# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Read CSV
joco_party_data_csv = "Resource/joco_party_data.csv"
joco_party_data_df = pd.read_csv(joco_party_data_csv)

# %%
#print dataframe
df = pd.DataFrame(joco_party_data_df)
print(df)
# Out:
#     Year Democrat Republican Libertarian Unaffiliated
# 0   2020  138,605    194,468       5,538      114,136
# 1   2019  113,911    181,868       4,873      117,604
# 2   2018  112,927    187,120       4,711      114,598
# 3   2017   95,890    177,619       4,109      116,097
# 4   2016   98,593    183,459       4,014      116,462
# 5   2015   84,061    172,333       3,394      114,845
# 6   2014   86,274    176,190       3,367      115,386
# 7   2013   83,831    172,300       2,990      112,674
# 8   2012   87,821    178,114       2,869      114,426
# 9   2011   84,386    169,449       2,450      105,717
# 10  2010   85,564    171,891       2,305      105,946
# 11  2009   83,106    164,422       2,033      104,535
# 12  2008   84,300    170,345       1,996      107,584
# 13  2007   69,732    163,260       1,799       97,660
# 14  2006   71,320    169,629       1,856       99,656
# 15  2005   69,504    167,979       1,778       97,199
# ...

# %%
figsize=(100, 100)

# %%
#Democrats 
plt.plot( 'Year', 'Democrat', data=df, marker='', color='blue', linewidth=2) 
#Republicans
plt.plot( 'Year', 'Republican', data=df, marker='', color='red', linewidth=2) 
#Unaffiliated
plt.plot( 'Year', 'Libertarian', data=df, marker='', color='yellow', linewidth=2,) 
#Libertarian
plt.plot( 'Year', 'Unaffiliated', data=df, marker='', color='purple', linewidth=2,) 

plt.legend()

# %%
plt.plot( 'Democrat', 'Year', data=df, marker='', color='blue', linewidth=2)
