# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Read CSV
joco_party_data_csv = "Resource/joco_party_data.csv"
joco_party_data_df = pd.read_csv(joco_party_data_csv)

# %%
#print dataframe
df = pd.DataFrame(joco_party_data_df)
print(df)
# Out:
#     Year Democrat Republican Libertarian Unaffiliated
# 0   1988   32,389     83,025          17       70,296
# 1   1990   32,210     85,987          59       85,987
# 2   1992   46,217    104,078         562       71,904
# 3   1994   45,806    105,905         739       68,419
# 4   1996   50,223    121,503       1,466       73,165
# 5   1998   55,744    134,683       1,590       81,982
# 6   2000   63,550    152,929       1,814       93,808
# 7   2002   67,582    165,705       1,959       98,129
# 8   2004   72,243    173,816       1,922      100,295
# 9   2005   69,504    167,979       1,778       97,199
# 10  2006   71,320    169,629       1,856       99,656
# 11  2007   69,732    163,260       1,799       97,660
# 12  2008   84,300    170,345       1,996      107,584
# 13  2009   83,106    164,422       2,033      104,535
# 14  2010   85,564    171,891       2,305      105,946
# 15  2011   84,386    169,449       2,450      105,717
# 16  2012   87,821    178,114       2,869      114,426
# 17  2013   83,831    172,300       2,990      112,674
# 18  2014   86,274    176,190       3,367      115,386
# 19  2015   84,061    172,333       3,394      114,845
# 20  2016   98,593    183,459       4,014      116,462
# 21  2017   95,890    177,619       4,109      116,097
# 22  2018  112,927    187,120       4,711      114,598
# 23  2019  113,911    181,868       4,873      117,604
# 24  2020  138,605    194,468       5,538      114,136

# %%
plt.figure(figsize=(10,10))
plt.plot( 'Year', 'Democrat', data=df, marker='', color='blue', linewidth=2)
plt.title("Democrats")
plt.xlabel("Year")
plt.ylabel("Number of Democratic Voters")
# Out:
# Text(0, 0.5, 'Number of Democratic Voters')

# %%
plt.figure(figsize=(10,10))
plt.plot( 'Year', 'Republican', data=df, marker='', color='red', linewidth=2) 
plt.title("Republicans")
plt.xlabel("Year")
plt.ylabel("Number of Republican Voters")
# Out:
# Text(0, 0.5, 'Number of Republican Voters')

# %%
plt.figure(figsize=(10,10))
plt.plot( 'Year', 'Libertarian', data=df, marker='', color='yellow', linewidth=2,)
plt.title("Libertarian")
plt.xlabel("Year")
plt.ylabel("Number of Libertarian Voters")
# Out:
# Text(0, 0.5, 'Number of Libertarian Voters')

# %%
plt.figure(figsize=(10,10))
plt.plot( 'Year', 'Unaffiliated', data=df, marker='', color='purple', linewidth=2,)
plt.title("Unaffiliated")
plt.xlabel("Year")
plt.ylabel("Number of Unaffiliated Voters")
# Out:
# Text(0, 0.5, 'Number of Unaffiliated Voters')

# %%
plt.figure(figsize=(30,30))
#Democrats 
plt.plot( 'Year', 'Democrat', data=df, marker='', color='blue', linewidth=2) 
#Republicans
plt.plot( 'Year', 'Republican', data=df, marker='', color='red', linewidth=2) 
#Unaffiliated
plt.plot( 'Year', 'Libertarian', data=df, marker='', color='yellow', linewidth=2) 
#Libertarian
plt.plot( 'Year', 'Unaffiliated', data=df, marker='', color='purple', linewidth=2) 

plt.legend()
plt.title("Johnson County Political Party Growth")
plt.xlabel("Year")
plt.ylabel("Number of Voters Registered Per Party")
#testing to see if this works.
# Out:
# Text(0, 0.5, 'Number of Voters Registered Per Party')
